# %%
import pandas as pd
import numpy as np

df = pd.read_csv("aggregated_1s_outliers_imputations_slopes.csv")
df.head(60)
# Out:
#               attr_time    attr_x     attr_y    attr_z   attr_lat  attr_lng  \
# 0   2015-03-11 07:58:34 -0.831786   4.875592  9.513959        NaN       NaN
# 1   2015-03-11 07:58:35 -0.858429   4.459560  9.043941        NaN       NaN
# 2   2015-03-11 07:58:36 -1.273464   4.266862  9.139566        NaN       NaN
# 3   2015-03-11 07:58:37 -0.664606   3.690015  9.443701        NaN       NaN
# 4   2015-03-11 07:58:38  0.006021   3.790752  9.341636        NaN       NaN
# 5   2015-03-11 07:58:39 -0.036711   3.941230  9.356865        NaN       NaN
# 6   2015-03-11 07:58:40 -0.785578   3.819465  9.402323        NaN       NaN
# 7   2015-03-11 07:58:41  0.179742   4.165734  9.271791        NaN       NaN
# 8   2015-03-11 07:58:42  0.246261   3.878069  9.373752        NaN       NaN
# 9   2015-03-11 07:58:43  0.235480   3.399255  9.546418        NaN       NaN
# 10  2015-03-11 07:58:44 -0.359346   3.708379  9.432484        NaN       NaN
# ...
